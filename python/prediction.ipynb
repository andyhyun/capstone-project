# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score

data = pd.read_sql('employees', 'postgresql://postgres:postgres@localhost:5432/sed')
data
# Out:
#         id    username          password first_name last_name           phone  \
# 0        1        andy       password123       Andy       Kim  (432) 564-7890
# 1        2     vincent       password123    Vincent     Loria    860-213-5665
# 2        3       larry       password123      Larry     Pautz    301-702-9892
# 3        4   florenced       password123   Florence     Denny    309-213-5665
# 4        5      bbony0      dY7|W%k\t(J9      Berte      Bony   (451) 5941195
# ...    ...         ...               ...        ...       ...             ...
# 999   1000    bekkelrn  oO7<!sn?8_OUv`1q      Berty     Ekkel   (717) 4401410
# 1000  1001     ibenero    fA7#oWYjlda7Fm       Iris      Bene   (355) 6258591
# 1001  1002     llloprp          lI5%fAyJ     Lucine      Llop   (775) 7811431
# 1002  1003    dcraigrq     wR2!_7<+Xr%_l    Deeanne     Craig   (152) 7872662
# 1003  1004  iizaksonrr        lW7}YcL'vt    Iormina   Izakson   (972) 3491638
#
# ...

# %%
X = data[['job', 'location']]
y = data['salary']

lr = LinearRegression()

X_encoded = pd.get_dummies(X)

X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

lr.fit(X_train, y_train)

y_pred = lr.predict(X_test)
y_pred
# Out:
# array([122610.1782072 , 114456.52364764, 139295.54256576, 144322.74586986,
#        123124.77128288, 137131.1782072 , 124067.35641439, 173362.35698098,
#        122825.47128288, 111428.29504384, 167761.69031431, 114367.23760959,
#        137131.1782072 , 137131.1782072 , 130391.20867914, 130829.71282878,
#        121522.8391036 , 108631.38754697, 102923.8391036 , 130240.57094293,
#        135216.34256576, 113689.22387806, 138535.67326125, 124757.8161184 ,
#        126673.1782072 , 176120.1828536 , 140567.45213813, 139747.85641439,
#        124264.95897554, 108631.38754697,  90016.57094293, 154651.5891036 ,
#        108274.14256576, 116645.8391036 , 112266.47128288, 130580.50542446,
#        112266.47128288, 158779.23760959, 141754.34256576, 137775.7320518 ,
#        134917.91253653, 128019.88298443, 113019.95897554, 155387.35641439,
#        126240.8161184 , 132702.67326125,  13890.15327727, 123741.57094293,
# ...

# %%
new_employee = pd.DataFrame({
    "job": ["Data Engineer"],
    "location": ["Hartford"],
})

employee = pd.DataFrame({})

new_employee_encoded = pd.get_dummies(new_employee)
for col in X_encoded.columns:
    employee[col] = [False]
    if col in new_employee_encoded.columns:
        employee[col] = [True]

predicted = lr.predict(employee)
print(predicted[0])
# Out:
# C:\Users\wasadmin\AppData\Local\Temp\2\ipykernel_1768\1110220112.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   employee[col] = [False]
# C:\Users\wasadmin\AppData\Local\Temp\2\ipykernel_1768\1110220112.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   employee[col] = [False]
# ...

# %%
import pickle

lr_file_path = 'lr.pkl'
xe_file_path = 'xe.pkl'

with open(lr_file_path, 'wb') as file:
    pickle.dump(lr, file)

with open(xe_file_path, 'wb') as file:
    pickle.dump(X_encoded, file)
